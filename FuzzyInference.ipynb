# %%
# Part 2 - Problem 1

import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzzy


x1 = np.linspace(-10, 10, 20)

x2 = np.linspace(-10, 10, 20)

sincvalues = np.outer(np.sin(x1), np.sin(x2)) / np.outer(x1, x2)

plt.plot (x1, sincvalues)
plt.show()

# %%
plt.plot (x2, sincvalues)
plt.show()

# %%
# Part 2 - Problem 2

x1 = np.linspace(1, 6, 20)

x2 = np.linspace(1, 6, 20)

x3 = np.linspace(1, 6, 20)

y = (1 + x1**0.5 + x2**-1 + x3**-1.5)**2


plt.plot (x1, y)
plt.plot (x2, y)
plt.plot (x3, y)
plt.show()
